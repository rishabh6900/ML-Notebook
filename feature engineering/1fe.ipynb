# %% [markdown]
# #  **Feature Engineering**

# %% [markdown]
# ![Screenshot 2024-12-26 134443.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-26 135248.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-12-26 135353.png](data:image/png;base64,...)

# %% [markdown]
# **Missing values inputation**

# %% [markdown]
# **Handling categorical values(One - hot encoding)**

# %% [markdown]
# **Outlier Detection**

# %% [markdown]
# **feature Scalling**

# %% [markdown]
# **Feature Construction**

# %% [markdown]
# **Feature Selection**

# %% [markdown]
# **Feature Extraction**
